# %%
import os
import sys
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
#os.listdir()
#Model type results
#MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")

Res_dir=os.path.join(MTR,"Test_8")
Losses=os.path.join(Res_dir,"loss_results.npy")

m_config=json.load(open(os.path.join(Res_dir,"config.json")))

# %%
#m_config
list(m_config["model"]["model_params"]["losses_weigths"].keys())
# Out:
# ['generative_loss']

# %%
model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

figure,axs=plt.subplots(1,1)

train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
axs.plot(np.log(train_losses[-30:]))
axs.plot(np.log(test_losses[-30:]))
#axs.plot((train_losses[-30:]))
#axs.plot((test_losses[-30:]))

# %%
#CHECK TRAIN TEST PERFORMANCE
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((train_losses[:400]),'r')
        axs.plot((test_losses[:400]),'b')
    except:
        print(t)

# %%
#CHECK TRAIN TEST PERFORMANCE
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((train_losses[150:]),'r')
        axs.plot((test_losses[150:]),'b')
    except:
        print(t)
# Out:
# Test_9
# Test_7

# %%
#Model comparison on test
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((test_losses[250:]),label=t)
        axs.legend()
    except:
        print(t)
# Out:
# Test_9
# Test_7

# %%
#Model comparison on test
figure,axs=plt.subplots(1,1,figsize=(10,10))
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((test_losses[:]),label=t)
        axs.legend()
    except:
        print(t)

# %%
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        print(t)
        print("TEST SCORE")
        print(train_losses[-1])
        print("TRAIN SCORE")
        print(test_losses[-1])
    except:
        print("ERROR")
        print(t)
# Out:
# Test_3
# TEST SCORE
# 169139.30715090092
# TRAIN SCORE
# 172901.83445945947
# Test_2
# TEST SCORE
# 253906.9082207207
# TRAIN SCORE
# 252124.88738738737
# Test_4
# TEST SCORE
# 85202.59244350283
# TRAIN SCORE
# 85534.59494650901
# Test_6
# TEST SCORE
# 226006.69263795044
# TRAIN SCORE
# 228359.38907657657
# Test_9
# TEST SCORE
# 173865.44847972973
# TRAIN SCORE
# 183122.6768018018
# Test_8
# TEST SCORE
# 140379.3540088384
# TRAIN SCORE
# 151856.916875
# Test_5
# TEST SCORE
# 271990.1423141892
# TRAIN SCORE
# 272522.6615990991
# Test_7
# TEST SCORE
# 143731.67785754506
# TRAIN SCORE
# 146661.44284909908
# Test_1
# TEST SCORE
# 253739.36570945944
# TRAIN SCORE
# 259241.4268018018

# %%
2732935.302631579
6899120.537162162
