# %%
import os
import sys
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
#os.listdir()
#Model type results
#MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")

Res_dir=os.path.join(MTR,"Test_7")
Losses=os.path.join(Res_dir,"loss_results.npy")

m_config=json.load(open(os.path.join(Res_dir,"config.json")))

# %%
#m_config
list(m_config["model"]["model_params"]["losses_weigths"].keys())
# Out:
# ['generative_loss']

# %%
model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

figure,axs=plt.subplots(1,1)

train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])
test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])
#axs.plot(np.log(train_losses[-1000:]))
#axs.plot(np.log(test_losses[-1000:]))
axs.plot((train_losses[:]))
axs.plot((test_losses[:]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-864da9a5b3eb> in <module>
#       3 figure,axs=plt.subplots(1,1)
#       4
# ----> 5 train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])
#       6 test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])
#       7 #axs.plot(np.log(train_losses[-1000:]))
#
# ~/Belugas/env/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Results/VAE/Basic_CNN_EDM/Test_7/loss_results.npy'

# %%
#CHECK TRAIN TEST PERFORMANCE
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((train_losses[-500:]),'r')
        axs.plot((test_losses[-500:]),'b')
    except:
        print(t)
# Out:
# Test_8

# %%
#CHECK TRAIN TEST PERFORMANCE
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])/m_config["trainer"]["batch_size"]
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((train_losses[250:]),'r')
        axs.plot((test_losses[250:]),'b')
    except:
        print(t)
# Out:
# Test_9
# Test_7

# %%
#Model comparison on test
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","Basic_CNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((test_losses[250:]),label=t)
        axs.legend()
    except:
        print(t)
# Out:
# Test_9
# Test_7

# %%
#Model comparison on test
figure,axs=plt.subplots(1,1)
MTR=os.path.join("..","..","Results","VAE","PCNN_EDM")
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])/m_config["trainer"]["batch_size"]
        axs.plot((test_losses[250:]),label=t)
        axs.legend()
    except:
        print(t)
# Out:
# Test_8

# %%
for t in os.listdir(MTR):
    t_res=os.path.join(MTR,t)
    Losses=os.path.join(t_res,"loss_results.npy")
    m_config=json.load(open(os.path.join(Res_dir,"config.json")))
    model_losses=list(m_config["model"]["model_params"]["losses_weigths"].keys())

    try:
        train_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["train"][model_losses[0]])
        test_losses=np.array(np.load(Losses,allow_pickle=True).tolist()["test"][model_losses[0]])
        print(t)
        print("TEST SCORE")
        print(train_losses[-1])
        print("TRAIN SCORE")
        print(test_losses[-1])
    except:
        print("ERROR")
        print(t)
# Out:
# Test_3
# TEST SCORE
# 8118686.743243244
# TRAIN SCORE
# 8299288.054054054
# Test_2
# TEST SCORE
# 12187531.594594594
# TRAIN SCORE
# 12101994.594594594
# ERROR
# Test_4
# Test_6
# TEST SCORE
# 10848321.246621622
# TRAIN SCORE
# 10961250.675675675
# ERROR
# Test_8
# Test_5
# TEST SCORE
# 13055526.831081081
# TRAIN SCORE
# 13081087.756756756
# Test_7
# TEST SCORE
# 6899120.537162162
# TRAIN SCORE
# 7039749.256756756
# Test_1
# TEST SCORE
# 12179489.554054054
# TRAIN SCORE
# 12443588.486486487

# %%
2732935.302631579
6899120.537162162
